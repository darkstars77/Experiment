# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

#weight initailization
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')


x = tf.placeholder(tf.float32, shape=[None, 784]) #mnist date
y_ = tf.placeholder(tf.float32, shape=[None, 10]) #ground truth

#1 conv layer
W_conv1 = weight_variable([5, 5, 1, 32]) #filter size, input channel, output channel
b_conv1 = bias_variable([32])

x_images = tf.reshape(x,[-1,28,28,1]) #img cnt, weight, height, channel

h1_conv = conv2d(x_images,W_conv1)+b_conv1
h1_pool = max_pool_2x2(h1_conv)

#h1_pool (?,14,14,32) 

#2 conv layer
W_conv2 = weight_variable([5, 5, 32, 64]) #filter size, input channel, output channel
b_conv2 = bias_variable([64])

h2_conv = conv2d(h1_pool,W_conv2) + b_conv2
h2_pool = max_pool_2x2(h2_conv)

#h2_pool(?,7,7,64)

#fc1 layer
W_fc1 = weight_variable([7*7*64, 1024])
b_fc1 = bias_variable([1024])

fc1_layer = tf.reshape(h2_pool,[-1,7*7*64])

fc1_layer_output = tf.matmul(fc1_layer,W_fc1) + b_fc1

#fc2 layer
W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

fc2_layer_output = tf.matmul(fc1_layer_output,W_fc2) + b_fc2

y = fc2_layer_output

#train and evaluate model
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=y,labels=y_)
train_step=tf.train.GradientDescentOptimizer(learning_rate=0.5).minimize(cross_entropy)

accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.arg_max(y,1),tf.arg_max(y_,1)),tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for i in range(5000):
        batch_x, batch_y = mnist.train.next_batch(50)
        _ , trainaccuracy = sess.run([train_step , accuracy] , feed_dict={x:batch_x, y_:batch_y})
        if i%10==0 :
            print('Step:%d train Accuracy : %g' % (i,trainaccuracy))
            
    
    print('\---Test Accuracy---\n')
    testaccuracy = sess.run(accuracy, feed_dict = {x:mnist.test.images , y_:mnist.test.labels})
    print('test Accuracy : %g' %(testaccuracy))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Step:0 train Accuracy : 0.06
# Step:10 train Accuracy : 0.12
# Step:20 train Accuracy : 0.1
# Step:30 train Accuracy : 0.04
# Step:40 train Accuracy : 0.14
# Step:50 train Accuracy : 0.06
# Step:60 train Accuracy : 0.14
# Step:70 train Accuracy : 0.14
# Step:80 train Accuracy : 0.2
# Step:90 train Accuracy : 0.12
# Step:100 train Accuracy : 0.12
# Step:110 train Accuracy : 0.1
# Step:120 train Accuracy : 0.2
# Step:130 train Accuracy : 0.1
# Step:140 train Accuracy : 0.08
# Step:150 train Accuracy : 0.1
# Step:160 train Accuracy : 0.12
# Step:170 train Accuracy : 0.1
# Step:180 train Accuracy : 0.08
# Step:190 train Accuracy : 0.1
# Step:200 train Accuracy : 0.1
# Step:210 train Accuracy : 0.16
# Step:220 train Accuracy : 0.06
# Step:230 train Accuracy : 0.16
# Step:240 train Accuracy : 0.1
# Step:250 train Accuracy : 0.16
# Step:260 train Accuracy : 0.08
# Step:270 train Accuracy : 0.12
# Step:280 train Accuracy : 0.16
# Step:290 train Accuracy : 0.1
# Step:300 train Accuracy : 0.06
# Step:310 train Accuracy : 0.1
# Step:320 train Accuracy : 0.06
# Step:330 train Accuracy : 0.2
# Step:340 train Accuracy : 0.14
# Step:350 train Accuracy : 0.06
# Step:360 train Accuracy : 0.1
# Step:370 train Accuracy : 0.1
# Step:380 train Accuracy : 0.06
# Step:390 train Accuracy : 0.1
# Step:400 train Accuracy : 0.08
# Step:410 train Accuracy : 0.1
# Step:420 train Accuracy : 0.1
# Step:430 train Accuracy : 0.08
# Step:440 train Accuracy : 0.04
# Step:450 train Accuracy : 0.06
# Step:460 train Accuracy : 0.12
# Step:470 train Accuracy : 0.12
# Step:480 train Accuracy : 0.06
# Step:490 train Accuracy : 0.08
# Step:500 train Accuracy : 0.08
# Step:510 train Accuracy : 0.04
# Step:520 train Accuracy : 0.08
# Step:530 train Accuracy : 0.1
# Step:540 train Accuracy : 0.06
# Step:550 train Accuracy : 0.1
# Step:560 train Accuracy : 0.1
# Step:570 train Accuracy : 0.12
# Step:580 train Accuracy : 0.14
# Step:590 train Accuracy : 0.16
# Step:600 train Accuracy : 0.06
# Step:610 train Accuracy : 0.1
# Step:620 train Accuracy : 0.1
# Step:630 train Accuracy : 0.12
# Step:640 train Accuracy : 0.06
# Step:650 train Accuracy : 0.1
# Step:660 train Accuracy : 0.1
# Step:670 train Accuracy : 0.08
# Step:680 train Accuracy : 0.12
# Step:690 train Accuracy : 0.08
# Step:700 train Accuracy : 0.14
# Step:710 train Accuracy : 0.04
# Step:720 train Accuracy : 0.1
# Step:730 train Accuracy : 0.04
# Step:740 train Accuracy : 0.1
# Step:750 train Accuracy : 0
# Step:760 train Accuracy : 0.08
# Step:770 train Accuracy : 0.06
# Step:780 train Accuracy : 0.12
# Step:790 train Accuracy : 0.06
# Step:800 train Accuracy : 0.06
# Step:810 train Accuracy : 0.18
# Step:820 train Accuracy : 0.12
# Step:830 train Accuracy : 0.04
# Step:840 train Accuracy : 0.1
# Step:850 train Accuracy : 0.02
# Step:860 train Accuracy : 0.1
# Step:870 train Accuracy : 0.14
# Step:880 train Accuracy : 0.08
# Step:890 train Accuracy : 0.12
# Step:900 train Accuracy : 0.1
# Step:910 train Accuracy : 0.14
# Step:920 train Accuracy : 0.18
# Step:930 train Accuracy : 0.08
# Step:940 train Accuracy : 0.14
# Step:950 train Accuracy : 0.06
# Step:960 train Accuracy : 0.08
# Step:970 train Accuracy : 0.16
# Step:980 train Accuracy : 0.08
# Step:990 train Accuracy : 0.1
# Step:1000 train Accuracy : 0.14
# Step:1010 train Accuracy : 0.08
# Step:1020 train Accuracy : 0.04
# Step:1030 train Accuracy : 0.1
# Step:1040 train Accuracy : 0.12
# Step:1050 train Accuracy : 0.1
# Step:1060 train Accuracy : 0.14
# Step:1070 train Accuracy : 0.12
# Step:1080 train Accuracy : 0.1
# Step:1090 train Accuracy : 0.08
# Step:1100 train Accuracy : 0.1
# Step:1110 train Accuracy : 0.04
# Step:1120 train Accuracy : 0.08
# Step:1130 train Accuracy : 0.08
# Step:1140 train Accuracy : 0.06
# Step:1150 train Accuracy : 0.08
# Step:1160 train Accuracy : 0.1
# Step:1170 train Accuracy : 0.12
# Step:1180 train Accuracy : 0.08
# Step:1190 train Accuracy : 0.1
# Step:1200 train Accuracy : 0.1
# Step:1210 train Accuracy : 0.04
# Step:1220 train Accuracy : 0.06
# Step:1230 train Accuracy : 0.08
# Step:1240 train Accuracy : 0.1
# Step:1250 train Accuracy : 0.16
# Step:1260 train Accuracy : 0.14
# Step:1270 train Accuracy : 0.1
# Step:1280 train Accuracy : 0.02
# Step:1290 train Accuracy : 0.12
# Step:1300 train Accuracy : 0.06
# Step:1310 train Accuracy : 0.2
# Step:1320 train Accuracy : 0.14
# Step:1330 train Accuracy : 0.04
# Step:1340 train Accuracy : 0.1
# Step:1350 train Accuracy : 0.16
# Step:1360 train Accuracy : 0.08
# Step:1370 train Accuracy : 0.08
# Step:1380 train Accuracy : 0.14
# Step:1390 train Accuracy : 0.16
# Step:1400 train Accuracy : 0.04
# Step:1410 train Accuracy : 0.14
# Step:1420 train Accuracy : 0.12
# Step:1430 train Accuracy : 0.08
# Step:1440 train Accuracy : 0.1
# Step:1450 train Accuracy : 0.02
# Step:1460 train Accuracy : 0.1
# Step:1470 train Accuracy : 0.1
# Step:1480 train Accuracy : 0.1
# Step:1490 train Accuracy : 0.08
# Step:1500 train Accuracy : 0.08
# Step:1510 train Accuracy : 0.12
# Step:1520 train Accuracy : 0.06
# Step:1530 train Accuracy : 0.16
# Step:1540 train Accuracy : 0.14
# Step:1550 train Accuracy : 0.1
# Step:1560 train Accuracy : 0.12
# Step:1570 train Accuracy : 0.04
# Step:1580 train Accuracy : 0.06
# Step:1590 train Accuracy : 0.12
# Step:1600 train Accuracy : 0.1
# Step:1610 train Accuracy : 0.08
# Step:1620 train Accuracy : 0.1
# Step:1630 train Accuracy : 0.06
# Step:1640 train Accuracy : 0.06
# Step:1650 train Accuracy : 0.1
# Step:1660 train Accuracy : 0.08
# Step:1670 train Accuracy : 0.1
# Step:1680 train Accuracy : 0.02
# Step:1690 train Accuracy : 0.18
# Step:1700 train Accuracy : 0.08
# Step:1710 train Accuracy : 0.14
# Step:1720 train Accuracy : 0.04
# Step:1730 train Accuracy : 0.08
# Step:1740 train Accuracy : 0.14
# Step:1750 train Accuracy : 0.1
# Step:1760 train Accuracy : 0.1
# Step:1770 train Accuracy : 0.02
# Step:1780 train Accuracy : 0.1
# Step:1790 train Accuracy : 0.1
# Step:1800 train Accuracy : 0.16
# Step:1810 train Accuracy : 0.04
# Step:1820 train Accuracy : 0.1
# Step:1830 train Accuracy : 0.16
# Step:1840 train Accuracy : 0.16
# Step:1850 train Accuracy : 0.18
# Step:1860 train Accuracy : 0.1
# Step:1870 train Accuracy : 0.08
# Step:1880 train Accuracy : 0.1
# Step:1890 train Accuracy : 0.04
# Step:1900 train Accuracy : 0.1
# Step:1910 train Accuracy : 0.1
# Step:1920 train Accuracy : 0.04
# Step:1930 train Accuracy : 0.06
# Step:1940 train Accuracy : 0.12
# Step:1950 train Accuracy : 0.12
# Step:1960 train Accuracy : 0.12
# Step:1970 train Accuracy : 0.14
# Step:1980 train Accuracy : 0.04
# Step:1990 train Accuracy : 0.1
# Step:2000 train Accuracy : 0.14
# Step:2010 train Accuracy : 0.04
# Step:2020 train Accuracy : 0.06
# Step:2030 train Accuracy : 0.1
# Step:2040 train Accuracy : 0.12
# Step:2050 train Accuracy : 0.08
# Step:2060 train Accuracy : 0.04
# Step:2070 train Accuracy : 0.08
# Step:2080 train Accuracy : 0.12
# Step:2090 train Accuracy : 0.08
# Step:2100 train Accuracy : 0.16
# Step:2110 train Accuracy : 0.08
# Step:2120 train Accuracy : 0.1
# Step:2130 train Accuracy : 0.08
# Step:2140 train Accuracy : 0.08
# Step:2150 train Accuracy : 0.18
# Step:2160 train Accuracy : 0.12
# Step:2170 train Accuracy : 0.1
# Step:2180 train Accuracy : 0.14
# Step:2190 train Accuracy : 0.12
# Step:2200 train Accuracy : 0.16
# Step:2210 train Accuracy : 0.08
# Step:2220 train Accuracy : 0.12
# Step:2230 train Accuracy : 0.12
# Step:2240 train Accuracy : 0.06
# Step:2250 train Accuracy : 0.12
# Step:2260 train Accuracy : 0.1
# Step:2270 train Accuracy : 0.08
# Step:2280 train Accuracy : 0.1
# Step:2290 train Accuracy : 0.02
# Step:2300 train Accuracy : 0.16
# Step:2310 train Accuracy : 0.08
# Step:2320 train Accuracy : 0.14
# Step:2330 train Accuracy : 0.08
# Step:2340 train Accuracy : 0.12
# Step:2350 train Accuracy : 0.14
# Step:2360 train Accuracy : 0.08
# Step:2370 train Accuracy : 0.04
# Step:2380 train Accuracy : 0.06
# Step:2390 train Accuracy : 0.1
# Step:2400 train Accuracy : 0.1
# Step:2410 train Accuracy : 0.16
# Step:2420 train Accuracy : 0.14
# Step:2430 train Accuracy : 0.04
# Step:2440 train Accuracy : 0.06
# Step:2450 train Accuracy : 0.06
# Step:2460 train Accuracy : 0.08
# Step:2470 train Accuracy : 0.18
# Step:2480 train Accuracy : 0.1
# Step:2490 train Accuracy : 0.08
# Step:2500 train Accuracy : 0.16
# Step:2510 train Accuracy : 0.04
# Step:2520 train Accuracy : 0.14
# Step:2530 train Accuracy : 0.02
# Step:2540 train Accuracy : 0.14
# Step:2550 train Accuracy : 0.02
# Step:2560 train Accuracy : 0.04
# Step:2570 train Accuracy : 0.08
# Step:2580 train Accuracy : 0.06
# Step:2590 train Accuracy : 0.08
# Step:2600 train Accuracy : 0.1
# Step:2610 train Accuracy : 0.12
# Step:2620 train Accuracy : 0.1
# Step:2630 train Accuracy : 0.08
# Step:2640 train Accuracy : 0.12
# Step:2650 train Accuracy : 0.06
# Step:2660 train Accuracy : 0.12
# Step:2670 train Accuracy : 0.08
# Step:2680 train Accuracy : 0.06
# Step:2690 train Accuracy : 0.1
# Step:2700 train Accuracy : 0.06
# Step:2710 train Accuracy : 0.14
# Step:2720 train Accuracy : 0.04
# Step:2730 train Accuracy : 0.12
# Step:2740 train Accuracy : 0.16
# Step:2750 train Accuracy : 0.2
# Step:2760 train Accuracy : 0.1
# Step:2770 train Accuracy : 0.12
# Step:2780 train Accuracy : 0.12
# Step:2790 train Accuracy : 0.12
# Step:2800 train Accuracy : 0.12
# Step:2810 train Accuracy : 0.06
# Step:2820 train Accuracy : 0.1
# Step:2830 train Accuracy : 0.08
# Step:2840 train Accuracy : 0.18
# Step:2850 train Accuracy : 0.12
# Step:2860 train Accuracy : 0.08
# Step:2870 train Accuracy : 0.08
# Step:2880 train Accuracy : 0.18
# Step:2890 train Accuracy : 0.12
# Step:2900 train Accuracy : 0.14
# Step:2910 train Accuracy : 0.06
# Step:2920 train Accuracy : 0.04
# Step:2930 train Accuracy : 0.1
# Step:2940 train Accuracy : 0.18
# Step:2950 train Accuracy : 0.1
# Step:2960 train Accuracy : 0.1
# Step:2970 train Accuracy : 0.1
# Step:2980 train Accuracy : 0.08
# Step:2990 train Accuracy : 0.14
# Step:3000 train Accuracy : 0.08
# Step:3010 train Accuracy : 0.22
# Step:3020 train Accuracy : 0.08
# Step:3030 train Accuracy : 0.1
# Step:3040 train Accuracy : 0.16
# Step:3050 train Accuracy : 0.06
# Step:3060 train Accuracy : 0.1
# Step:3070 train Accuracy : 0.12
# Step:3080 train Accuracy : 0.08
# Step:3090 train Accuracy : 0.1
# Step:3100 train Accuracy : 0.1
# Step:3110 train Accuracy : 0.02
# Step:3120 train Accuracy : 0.16
# Step:3130 train Accuracy : 0.12
# Step:3140 train Accuracy : 0.1
# Step:3150 train Accuracy : 0.06
# Step:3160 train Accuracy : 0.04
# Step:3170 train Accuracy : 0.1
# Step:3180 train Accuracy : 0.14
# Step:3190 train Accuracy : 0.06
# Step:3200 train Accuracy : 0.14
# Step:3210 train Accuracy : 0.06
# Step:3220 train Accuracy : 0.18
# Step:3230 train Accuracy : 0.14
# Step:3240 train Accuracy : 0.06
# Step:3250 train Accuracy : 0.12
# Step:3260 train Accuracy : 0.12
# Step:3270 train Accuracy : 0.08
# Step:3280 train Accuracy : 0.08
# Step:3290 train Accuracy : 0.14
# Step:3300 train Accuracy : 0.06
# Step:3310 train Accuracy : 0.1
# Step:3320 train Accuracy : 0.12
# Step:3330 train Accuracy : 0.06
# Step:3340 train Accuracy : 0.04
# Step:3350 train Accuracy : 0.1
# Step:3360 train Accuracy : 0.12
# Step:3370 train Accuracy : 0.16
# Step:3380 train Accuracy : 0.12
# Step:3390 train Accuracy : 0.18
# Step:3400 train Accuracy : 0.08
# Step:3410 train Accuracy : 0.1
# Step:3420 train Accuracy : 0.2
# Step:3430 train Accuracy : 0.06
# Step:3440 train Accuracy : 0.08
# Step:3450 train Accuracy : 0.08
# Step:3460 train Accuracy : 0.18
# Step:3470 train Accuracy : 0.06
# Step:3480 train Accuracy : 0.16
# Step:3490 train Accuracy : 0.04
# Step:3500 train Accuracy : 0.18
# Step:3510 train Accuracy : 0.1
# Step:3520 train Accuracy : 0.18
# Step:3530 train Accuracy : 0.1
# Step:3540 train Accuracy : 0.08
# Step:3550 train Accuracy : 0.06
# Step:3560 train Accuracy : 0.06
# Step:3570 train Accuracy : 0.12
# Step:3580 train Accuracy : 0.08
# Step:3590 train Accuracy : 0.08
# Step:3600 train Accuracy : 0.02
# Step:3610 train Accuracy : 0.1
# Step:3620 train Accuracy : 0.14
# Step:3630 train Accuracy : 0.16
# Step:3640 train Accuracy : 0.04
# Step:3650 train Accuracy : 0.08
# Step:3660 train Accuracy : 0.14
# Step:3670 train Accuracy : 0.12
# Step:3680 train Accuracy : 0.08
# Step:3690 train Accuracy : 0.12
# Step:3700 train Accuracy : 0.1
# Step:3710 train Accuracy : 0.1
# Step:3720 train Accuracy : 0
# Step:3730 train Accuracy : 0.12
# Step:3740 train Accuracy : 0.16
# Step:3750 train Accuracy : 0.1
# Step:3760 train Accuracy : 0.06
# Step:3770 train Accuracy : 0.1
# Step:3780 train Accuracy : 0.08
# Step:3790 train Accuracy : 0.1
# Step:3800 train Accuracy : 0.1
# Step:3810 train Accuracy : 0.16
# Step:3820 train Accuracy : 0.02
# Step:3830 train Accuracy : 0
# Step:3840 train Accuracy : 0.08
# Step:3850 train Accuracy : 0.06
# Step:3860 train Accuracy : 0.16
# Step:3870 train Accuracy : 0.14
# Step:3880 train Accuracy : 0.16
# Step:3890 train Accuracy : 0.06
# Step:3900 train Accuracy : 0.1
# Step:3910 train Accuracy : 0.12
# Step:3920 train Accuracy : 0.1
# Step:3930 train Accuracy : 0.1
# Step:3940 train Accuracy : 0.12
# Step:3950 train Accuracy : 0.06
# Step:3960 train Accuracy : 0.1
# Step:3970 train Accuracy : 0.04
# Step:3980 train Accuracy : 0.12
# Step:3990 train Accuracy : 0.08
# Step:4000 train Accuracy : 0.14
# Step:4010 train Accuracy : 0.12
# Step:4020 train Accuracy : 0.18
# Step:4030 train Accuracy : 0.06
# Step:4040 train Accuracy : 0.12
# Step:4050 train Accuracy : 0.12
# Step:4060 train Accuracy : 0.1
# Step:4070 train Accuracy : 0.14
# Step:4080 train Accuracy : 0.04
# Step:4090 train Accuracy : 0.04
# Step:4100 train Accuracy : 0.06
# Step:4110 train Accuracy : 0.16
# Step:4120 train Accuracy : 0.12
# Step:4130 train Accuracy : 0.1
# Step:4140 train Accuracy : 0.08
# Step:4150 train Accuracy : 0.1
# Step:4160 train Accuracy : 0.1
# Step:4170 train Accuracy : 0.16
# Step:4180 train Accuracy : 0.12
# Step:4190 train Accuracy : 0.14
# Step:4200 train Accuracy : 0.2
# Step:4210 train Accuracy : 0.1
# Step:4220 train Accuracy : 0.16
# Step:4230 train Accuracy : 0.12
# Step:4240 train Accuracy : 0.1
# Step:4250 train Accuracy : 0.1
# Step:4260 train Accuracy : 0.1
# Step:4270 train Accuracy : 0.08
# Step:4280 train Accuracy : 0.06
# Step:4290 train Accuracy : 0.1
# Step:4300 train Accuracy : 0.1
# Step:4310 train Accuracy : 0.1
# Step:4320 train Accuracy : 0.12
# Step:4330 train Accuracy : 0.08
# Step:4340 train Accuracy : 0.08
# Step:4350 train Accuracy : 0.12
# Step:4360 train Accuracy : 0.1
# Step:4370 train Accuracy : 0.08
# Step:4380 train Accuracy : 0.08
# Step:4390 train Accuracy : 0.04
# Step:4400 train Accuracy : 0.12
# Step:4410 train Accuracy : 0.12
# Step:4420 train Accuracy : 0.2
# Step:4430 train Accuracy : 0.08
# Step:4440 train Accuracy : 0.1
# Step:4450 train Accuracy : 0.06
# Step:4460 train Accuracy : 0.08
# Step:4470 train Accuracy : 0.1
# Step:4480 train Accuracy : 0.08
# Step:4490 train Accuracy : 0.1
# Step:4500 train Accuracy : 0.12
# Step:4510 train Accuracy : 0.12
# Step:4520 train Accuracy : 0.1
# Step:4530 train Accuracy : 0.08
# Step:4540 train Accuracy : 0.1
# Step:4550 train Accuracy : 0.08
# Step:4560 train Accuracy : 0.12
# Step:4570 train Accuracy : 0.12
# Step:4580 train Accuracy : 0.1
# Step:4590 train Accuracy : 0.1
# Step:4600 train Accuracy : 0.06
# Step:4610 train Accuracy : 0.18
# Step:4620 train Accuracy : 0.1
# Step:4630 train Accuracy : 0.08
# Step:4640 train Accuracy : 0.12
# Step:4650 train Accuracy : 0.12
# Step:4660 train Accuracy : 0.1
# Step:4670 train Accuracy : 0.16
# Step:4680 train Accuracy : 0.04
# Step:4690 train Accuracy : 0.04
# Step:4700 train Accuracy : 0.06
# Step:4710 train Accuracy : 0.1
# Step:4720 train Accuracy : 0.1
# Step:4730 train Accuracy : 0.06
# Step:4740 train Accuracy : 0.1
# Step:4750 train Accuracy : 0.1
# Step:4760 train Accuracy : 0.22
# Step:4770 train Accuracy : 0.04
# Step:4780 train Accuracy : 0.12
# Step:4790 train Accuracy : 0.06
# Step:4800 train Accuracy : 0.04
# Step:4810 train Accuracy : 0.04
# Step:4820 train Accuracy : 0.08
# Step:4830 train Accuracy : 0.1
# Step:4840 train Accuracy : 0.1
# Step:4850 train Accuracy : 0.14
# Step:4860 train Accuracy : 0.1
# Step:4870 train Accuracy : 0.08
# Step:4880 train Accuracy : 0.06
# Step:4890 train Accuracy : 0.08
# Step:4900 train Accuracy : 0.04
# Step:4910 train Accuracy : 0.14
# Step:4920 train Accuracy : 0.04
# Step:4930 train Accuracy : 0.12
# Step:4940 train Accuracy : 0.14
# Step:4950 train Accuracy : 0.14
# Step:4960 train Accuracy : 0.08
# Step:4970 train Accuracy : 0.1
# Step:4980 train Accuracy : 0.14
# Step:4990 train Accuracy : 0.1
# \---Test Accuracy---
#
# test Accuracy : 0.098
